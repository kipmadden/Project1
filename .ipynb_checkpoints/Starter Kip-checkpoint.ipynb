# %%
import pandas as pd

# %%
df = pd.read_excel('data/2019.xls', header = [0,1], sheet_name='Additional Measure Data')

# %%
df.head(10)
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Life expectancy  \
#                 FIPS              State             County Life Expectancy
# 0              48000              Texas                NaN       79.021563
# 1              48001              Texas           Anderson       73.773772
# 2              48003              Texas            Andrews       76.756795
# 3              48005              Texas           Angelina       76.336820
# 4              48007              Texas            Aransas       76.912561
# 5              48009              Texas             Archer       77.039463
# 6              48011              Texas          Armstrong       72.397526
# 7              48013              Texas           Atascosa       78.281969
# 8              48015              Texas             Austin       79.101814
# 9              48017              Texas             Bailey       78.397363
#
#                                                       \
# ...

# %%
df.drop(0, inplace = True)

# %%
df.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Life expectancy  \
#                 FIPS              State             County Life Expectancy
# 1              48001              Texas           Anderson       73.773772
# 2              48003              Texas            Andrews       76.756795
# 3              48005              Texas           Angelina       76.336820
# 4              48007              Texas            Aransas       76.912561
# 5              48009              Texas             Archer       77.039463
#
#                                                       \
#   95% CI - Low 95% CI - High Life Expectancy (Black)
# 1    73.075431     74.472113               70.933226
# 2    75.377601     78.135988                     NaN
# 3    75.722123     76.951517               72.360092
# 4    75.793952     78.031171                     NaN
# 5    74.784054     79.294872                     NaN
#
#                                                       \
# ...

# %%
ndf = pd.DataFrame()

# %%
ndf['County'] = df[('Unnamed: 2_level_0', 'County')]
ndf
# Out:
#        County
# 1    Anderson
# 2     Andrews
# 3    Angelina
# 4     Aransas
# 5      Archer
# ..        ...
# 250      Wood
# 251    Yoakum
# 252     Young
# 253    Zapata
# 254    Zavala
#
# [254 rows x 1 columns]

# %%
shane_df = pd.read_excel('data/Shane.xlsx', header = [0], sheet_name='RVU')

# %%
shane_df['Status'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 252    False
# 253    False
# 254     True
# 255    False
# 256    False
# Name: Status, Length: 257, dtype: bool

# %%
sdf = shane_df[['County','Status']]
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 2 columns):
# County    256 non-null object
# Status    256 non-null object
# dtypes: object(2)
# memory usage: 4.1+ KB

# %%
sdf = sdf.dropna()

# %%
sdf
# Out:
#        County Status
# 0    Anderson  Rural
# 1     Andrews  Rural
# 2    Angelina  Rural
# 3     Aransas  Urban
# 4      Archer  Urban
# ..        ...    ...
# 251     Young  Rural
# 252    Zapata  Rural
# 253    Zavala  Rural
# 255
# 256
#
# [256 rows x 2 columns]

# %%
sdf.loc[sdf['County'] == 'De Witt', ['County']] = ('DeWitt')

# %%
sdf.loc[sdf['County'] == 'DeWitt']
# Out:
#     County Status
# 58  DeWitt  Rural

# %%
ndf
# Out:
# Empty DataFrame
# Columns: []
# Index: []
